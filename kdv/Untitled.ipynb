# %%
run kdv
# Out:
# Current process ID: 17440
# /data/home/liuyulong/auto_discovery/kdv/001_G_17440
# Using device: cuda:0
# load module
# load data with noise = 0 Nm = 5000 Nf = 5000
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
# Iter 0, Loss: 3.85671e-01, Loss_m: 3.83439e-02, Loss_f: 2.22387e+00,Loss_ut: 1.24940e-01,Loss_l: 1.600e+01,lam:1.59600e+01,u_tt_norm:5.305e-03, time: 0.06
# log_loss_f_min 0.0 log_loss_min -0.9527693174806275
# Iter 1000, Loss: 9.37087e-04, Loss_m: 3.75075e-04, Loss_f: 1.41560e-03,Loss_ut: 4.20436e-04,Loss_l: 1.515e+01,lam:1.51478e+01,u_tt_norm:5.305e-03, time: 68.54
# log_loss_f_min -6.654984912908068 log_loss_min -6.97287557157141
# ...
